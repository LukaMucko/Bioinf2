# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("alignment_results/reference.csv")
LENGTH = 4641652

# %%
data["percentage"] = data["score"] / LENGTH * 100

# %%
avg_data = data.groupby('k')['percentage'].mean().reset_index()

plt.figure(figsize=(10, 8))
plt.plot(avg_data['k'].astype(str), avg_data['percentage'], marker='o')
plt.title('Average Alignment Score Percentage by k Reference')
plt.xlabel('k')
plt.ylabel('Percentage')
plt.ylim(0, 110)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('reference.png')
plt.show()

# %%
data = pd.read_csv("alignment_results/ont.csv")
LENGTH = 46572832
data["percentage"] = data["score"] / LENGTH * 100
avg_data = data.groupby('k')['percentage'].mean().reset_index()

# %%
plt.figure(figsize=(10, 8))
plt.plot(avg_data['k'].astype(str), avg_data['percentage'], marker='o')
plt.title('Average Alignment Score Percentage by k Reference')
plt.xlabel('k')
plt.ylabel('Percentage')
plt.ylim(0, 110)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('ONT.png')
plt.show()

# %%
data = pd.read_csv("alignment_results/pb.csv")
LENGTH = 47933164
data["percentage"] = data["score"] / LENGTH * 100
data.dropna(inplace=True)
avg_data = data.groupby('k')['percentage'].mean().reset_index()

plt.figure(figsize=(10, 8))
plt.plot(avg_data['k'].astype(str), avg_data['percentage'], marker='o')
plt.title('Average Alignment Score Percentage by k Reference')
plt.xlabel('k')
plt.ylabel('Percentage')
plt.ylim(0, 110)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('PB.png')
plt.show()
